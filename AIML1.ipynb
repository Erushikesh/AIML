# %% [markdown]
# <a href="https://colab.research.google.com/github/Erushikesh/AIML/blob/main/AIML1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Part 1 – Implement Basic Data Structures using Numpy, Pandas

# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt

# Define a sample array
x = np.linspace(0.1, 10, 100)

# Perform sine operation
y_sin = np.sin(x)

# Perform logarithm operation
y_log = np.log(x)

# Perform exponential operation
y_exp = np.exp(x)

# Plot the results
plt.figure(figsize=(12, 6))

# %%
# Plot sine
plt.subplot(1, 3, 1)
plt.plot(x, y_sin, label='sin(x)')
plt.title('Sine Function')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.legend()

# Plot logarithm
plt.subplot(1, 3, 2)
plt.plot(x, y_log, label='log(x)', color='orange')
plt.title('Logarithm Function')
plt.xlabel('x')
plt.ylabel('log(x)')
plt.legend()

# Plot exponential
plt.subplot(1, 3, 3)
plt.plot(x, y_exp, label='exp(x)', color='green')
plt.title('Exponential Function')
plt.xlabel('x')
plt.ylabel('exp(x)')
plt.legend()

# Show plots
plt.tight_layout()
plt.show()

# %%
# Part 2: Program 1
# First, you need to install the pandas library if you haven't already
# !pip install pandas
# Import the pandas library
import pandas as pd
# Define the data
people = ['Kiran', 'Arun', 'Vijay', 'Varun']
age = [25, 30, 35, 40]
height = [145, 151, 165, 173]
weight = [45, 55, 65, 75]
# Create a DataFrame
data = {
    'Name': people,
    'Age': age,
    'Height': height,
    'Weight': weight
}
df = pd.DataFrame(data)
# Display the DataFrame
print(df)
# Out:
# ...
#     Name  Age  Height  Weight
# 0  Kiran   25     145      45
# 1   Arun   30     151      55
# 2  Vijay   35     165      65
# 3  Varun   40     173      75

# %%
# 3. Scatter Plot: Age vs Weight
plt.figure(figsize=(8, 6))
plt.scatter(df['Age'], df['Weight'], color='blue', marker='o')
plt.title('Scatter Plot of Age vs Weight')
plt.xlabel('Age (years)')
plt.ylabel('Weight (kg)')
plt.grid(True)
plt.show()

# %%
# 4. Bar Chart: Height of Individuals
plt.figure(figsize=(8, 6))
plt.bar(df['Name'], df['Height'], color='green')
plt.title('Bar Chart of Individuals\' Heights')
plt.xlabel('Name')
plt.ylabel('Height (cm)')
plt.show()

# %%
# 5. Histogram: Distribution of Age
plt.figure(figsize=(8, 6))
plt.hist(df['Age'], bins=5, color='orange', edgecolor='black')
plt.title('Histogram of Age Distribution')
plt.xlabel('Age (years)')
plt.ylabel('Frequency')
plt.show()

# %%
#part3-program1

# Install necessary packages in Colab
# !pip install pandas openpyxl

# Import necessary libraries
import pandas as pd

# Mount Google Drive to access your files
from google.colab import drive
drive.mount('/content/drive')

# Access the file from Google Drive
excel_file_path = '/content/drive/My Drive/your_file.xlsx'  # replace with your file path
data_excel = pd.read_excel(excel_file_path)
print(data_excel)

# %%
# Upload a .tsv file
from google.colab import files
uploaded = files.upload()

# Read the .tsv file
import io
df_tsv = pd.read_csv(io.BytesIO(uploaded['your_file.tsv']), delimiter='\t')
print(df_tsv)
# Out:
#      <input type="file" id="files-e7fd4cb4-f1d0-445c-8486-2f40150895e4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e7fd4cb4-f1d0-445c-8486-2f40150895e4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Upload a .csv file
uploaded = files.upload()

# Read the .csv file
df_csv = pd.read_csv(io.BytesIO(uploaded['your_file.csv']))
print(df_csv)

# %%
# Upload an .xlsx file
uploaded = files.upload()

# Read the Excel file
df_excel = pd.read_excel(io.BytesIO(uploaded['your_file.xlsx']))
print(df_excel)

# %%
# Load data from a URL
url = 'https://example.com/your_file.csv'  # replace with actual URL
df_from_url = pd.read_csv(url)
print(df_from_url)
